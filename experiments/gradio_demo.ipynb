# %%
import gradio as gr

# %%
def greet(name, intensity):
    return "Hello, " + name + "!" * int(intensity)

demo = gr.Interface(
    fn=greet,
    inputs=["text", "slider"],
    outputs=["text"],
)

demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
# Running on public URL: https://1f93a48e51dfc66ad9.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1f93a48e51dfc66ad9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            image = gr.Image(label="Input Image")
            with gr.Row():
                button_2 = gr.Button(interactive=True, value="Clear")
                button = gr.Button(value="Segment")
        image_2 = gr.Image(label="Segmented Output")

    @gr.on([button.click], inputs=[image], outputs=[image_2])
    def fn_1(image):
        ...
        return ...

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
